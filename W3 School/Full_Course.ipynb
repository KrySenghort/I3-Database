# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd 
import numpy as np 
import sqlite3 as sq

# %%
sheet_id = "1CS4VyTmL8W34ipGFMxNhNT-y0f-KEo8bXb8SU6Tv5qk"
csv_url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/export?format=csv"
df = pd.read_csv(csv_url)
df
# Out:
#     CustomerID                        CustomerName         ContactName  \
# 0            1                 Alfreds Futterkiste        Maria Anders
# 1            2  Ana Trujillo Emparedados y helados        Ana Trujillo
# 2            3             Antonio Moreno Taquería      Antonio Moreno
# 3            4                     Around the Horn        Thomas Hardy
# 4            5                  Berglunds snabbköp  Christina Berglund
# ..         ...                                 ...                 ...
# 86          87                      Wartian Herkku    Pirkko Koskitalo
# 87          88              Wellington Importadora       Paula Parente
# 88          89                White Clover Markets      Karl Jablonski
# 89          90                         Wilman Kala     Matti Karttunen
# 90          91                              Wolski             Zbyszek
#
#                           Address         City PostalCode  Country
# ...

# %%
# We will sqlite3 library and create a connection
cnn = sq.connect('jupyter_sql_w3_school_tutorial.db')

# %%
df.to_sql('customer', cnn)
# %load_ext sql
# %sql sqlite:///jupyter_sql_w3_school_tutorial.db

# %% [markdown]
# ## Display the info of customer

# %%
# %%sql
# SELECT * FROM customer;
# Out:
#  * sqlite:///jupyter_sql_w3_school_tutorial.db
# Done.
# [(0, 1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany'),
#  (1, 2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '5021', 'Mexico'),
#  (2, 3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '5023', 'Mexico'),
#  (3, 4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK'),
#  (4, 5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden'),
#  (5, 6, 'Blauer See Delikatessen', 'Hanna Moos', 'Forsterstr. 57', 'Mannheim', '68306', 'Germany'),
#  (6, 7, 'Blondel père et fils', 'Frédérique Citeaux', '24, place Kléber', 'Strasbourg', '67000', 'France'),
#  (7, 8, 'Bólido Comidas preparadas', 'Martín Sommer', 'C/ Araquil, 67', 'Madrid', '28023', 'Spain'),
# ...

# %%
df.to_csv('dataset.csv')

# %%
# %%sql
# CREATE TABLE customers (
#     CustomerID INT PRIMARY KEY,
#     CustomerName TEXT,
#     City TEXT,
#     Country TEXT
# );
# Out:
#  * sqlite:///jupyter_sql_w3_school_tutorial.db
# Done.
# []

# %%
# %%sql
# SELECT * FROM customer;
#
# LOAD DATA INFILE 'dataset.csv' INTO TABLE customer
# FIELDS TERMINATED BY ',' IGNORE 1 LINES;    # use to import data into sql
#
# SHOW VARIABLES LIKE 'secure_file_priv';
# Out:
#  * sqlite:///jupyter_sql_w3_school_tutorial.db
# Done.
# (sqlite3.OperationalError) near "LOAD": syntax error
# [SQL: LOAD DATA INFILE 'dataset.csv' INTO TABLE customer
# FIELDS TERMINATED BY ',' IGNORE 1 LINES;    # use to import data into sql]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# %%sql
# SELECT CustomerName, City, Country FROM customers;
# Out:
#  * sqlite:///jupyter_sql_w3_school_tutorial.db
# Done.
# []
